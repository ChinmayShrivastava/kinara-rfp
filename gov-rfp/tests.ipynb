# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
from IPython.display import display, Markdown

display(Markdown(nodes_with_scores[0].node.text))
# Out:
# 2032H323R00065 – AMENDMENT 1
# 81 of 91
#  2.6  Page Limits Matrix
#
# Table 3.4
# Proposal
# Volume Volume Title Page Limit
# I Cover Letter  2 pages for Cover
# Letter
# II Technical Approach
# Volume  5 Pages
# III Management Approach
# Volume 3 pages
# IV Past Performance Volume  Past Performance
# Reference
# Attachments (3
# pages)
# V Completed RFP and Price
# Volume  No page limit
#
# 2.6.1  Page Limitations
#
# Page limitations shall be treated as maximums.  If exceeded, the excess pages will not be read or
# considered in the evaluation or award decision of the proposal.  Each page shall be counted
# except introductory letter(s), cover pages, table of contents, list of tables or drawings, tabs, and
# glossaries, unless otherwise noted in this provision.
#
# 3.0 EVALUATION FACTORS FOR AWARD
#
# 3.1.

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-4")

prompt = (
    "Based on the the excerpt from the RFP, answer the question:"
    "\n"
    "---------------------------------------------\n"
    "Excerpt:\n"
    "{excerpt}"
    "\n"
    "---------------------------------------------\n"
    "{question}"
    "\n"
    "---------------------------------------------\n"
    "Answer:"
    )

# %%
question = "What are the page limits?"
nodes_with_scores = retriever.retrieve(
    question
)
display(Markdown(llm.complete(prompt.format(excerpt=nodes_with_scores[0].node.text, question=question)).text))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Generated queries:
# 1. What are the page limits for academic journals?
# 2. How to determine page limits for a research paper?
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The page limits are as follows: 2 pages for the Cover Letter (Volume I), 5 pages for the Technical Approach Volume (Volume II), 3 pages for the Management Approach Volume (Volume III), and Past Performance Reference Attachments (3 pages) for the Past Performance Volume (Volume IV). There is no page limit for the Completed RFP and Price Volume (Volume V).

# %%
question = "What are the formating requirements?"
nodes_with_scores = retriever.retrieve(
    question
)
display(Markdown(llm.complete(prompt.format(excerpt=nodes_with_scores[0].node.text, question=question)).text))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generated queries:
# 1. How to properly format a document according to APA guidelines?
# 2. What are the formatting rules for creating a professional resume?
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The formatting requirements are to use 8.5”x11” size paper, single spaced, with 1” margins all around. The text should be no smaller than 12-point font.

# %%
nodes_with_scores
# Out:
# [NodeWithScore(node=TextNode(id_='ca5b704f-8a54-4746-b103-3046a7597ac4', embedding=None, metadata={'page_label': '75', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5c1f0dc9-5f25-474e-b05c-14d8899f39bf', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '75', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, hash='1075cb56f0c304896e70dda7e454653a0b6a7b250b0538bd830d1bbeb7dd5278'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='01bd0be3-c945-483d-82df-a47a292fcab1', node_type=<ObjectType.TEXT: '1'>, metadata={'page_label': '75', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, hash='59fb9854996e69c17262e0222e86bdfe93b6946f5a868a77b55511f25acbe058'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='dfeec777-3330-4903-bfa9-439836ca6977', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='80764d6112a5a320bbf8ecd7691562ce9273e76028b3644d8ca96b0eb6b0fca4')}, text='2.1.3 Page Size and Format   \n  \nThe proposals shall be prepared using the following format: \n \n\uf0b7 Use 8.5”x11” size paper, single spaced; \n\uf0b7 Use 1” margins all around; \n\uf0b7 Text shall be no smaller than 12-point font;', start_char_idx=2003, end_char_idx=2218, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.6666666666666666),
#  NodeWithScore(node=TextNode(id_='dfeec777-3330-4903-bfa9-439836ca6977', embedding=None, metadata={'page_label': '76', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='bcb1b95e-ec7c-432b-b870-7edd28e88b02', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '76', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, hash='f80b64da95c892a86262ed2f48444abd7378780b055347e625e5b862b691e94a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='ca5b704f-8a54-4746-b103-3046a7597ac4', node_type=<ObjectType.TEXT: '1'>, metadata={'page_label': '75', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, hash='9edad5e77d13479ba0298ef85ddd04e8b713abe44e520dc1535420c572494813'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='85b68119-25bb-46fd-8b93-238de5063e3c', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='71ca6008711b4efdab4803b0ab99112fa1d8f1291119bd398e6c1bcf407d8497')}, text='2032H323R00065 – AMENDMENT 1   \n76 of 91 \n \uf0b7 Font style and size for illustrations, drawings, and tables are at the Offeror’s discretion, \nbut all labels and markings must be easily readable. Color may be used at the discretion \nof the Offeror. \n \nEvery page, except for the Title Page, shall contain a page number. Blank pages will contain the \nmarking “Page Intentionally Left Blank.” Every page will contain the Offeror’s name and the \nRFP number. It is the Offeror’s responsibility to ensure data considered sensitive is marked as \nsuch. These markings may appear only in the margins. The Offeror shall include the point of \ncontact (name, telephone number, e-mail address, and fax number) that can assist the CO with \nquestions/problems associated with the Offeror’s quote submission. \n \n*Submissions shall be via email in MS Word, MS Excel, and/or .pdf format.', start_char_idx=0, end_char_idx=866, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.0)]

# %%
question = "What are the formating requirements? Also what are the page limits?"
nodes_with_scores = retriever.retrieve(
    question
)
_excerpt = ''
i = 0
for node in nodes_with_scores:
    _excerpt += f"Evidence {i+1}:\n"
    _excerpt += node.node.text
    _excerpt += "\n"
    i += 1
display(Markdown(llm.complete(prompt.format(excerpt=_excerpt, question=question)).text))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generated queries:
# 1. What are the formatting guidelines for academic papers?
# 2. How many pages are typically allowed for a research proposal?
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The formatting requirements for the proposal are as follows:
#
# - Use 8.5”x11” size paper, single spaced
# - Use 1” margins all around
# - Text shall be no smaller than 12-point font
# - Font style and size for illustrations, drawings, and tables are at the Offeror’s discretion, but all labels and markings must be easily readable
# - Every page, except for the Title Page, shall contain a page number
# - Blank pages will contain the marking “Page Intentionally Left Blank”
# - Every page will contain the Offeror’s name and the RFP number
# - The Offeror shall include the point of contact (name, telephone number, e-mail address, and fax number) that can assist the CO with questions/problems associated with the Offeror’s quote submission
# - Submissions shall be via email in MS Word, MS Excel, and/or .pdf format
#
# The page limits are as follows:
#
# - Cover Letter: 2 pages
# - Technical Approach Volume: 5 pages
# - Management Approach Volume: 3 pages
# - Past Performance Volume: Past Performance Reference Attachments (3 pages)
# - Completed RFP and Price Volume: No page limit
#
# If the page limits are exceeded, the excess pages will not be read or considered in the evaluation or award decision of the proposal.

# %%
nodes_with_scores
# Out:
# [NodeWithScore(node=TextNode(id_='d49f1355-cd14-4843-9984-be038fd19682', embedding=None, metadata={'page_label': '81', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6cbedb30-768c-4211-bc58-aaf10beb1238', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '81', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, hash='a3b137aefe54743d9949c991d4848ae9e762fb4961dcb0753ba06665c770206a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='66b0f482-02bd-43fa-b9ec-0399275ba218', node_type=<ObjectType.TEXT: '1'>, metadata={'page_label': '80', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, hash='3d2262c1dc412ea46e757392a646282079d451fda778e3fceddf2fb91b5f8913'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='65e02d34-8871-4e0c-ae51-dfed714ffdaa', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='d58342e488282c3afec38eaf2854b8f302e375cec2a99e944739aec043e834e2')}, text='2032H323R00065 – AMENDMENT 1   \n81 of 91 \n 2.6  Page Limits Matrix  \n \nTable 3.4 \nProposal \nVolume Volume Title Page Limit \nI Cover Letter  2 pages for Cover  \nLetter   \nII Technical Approach  \nVolume  5 Pages  \nIII Management Approach \nVolume 3 pages \nIV Past Performance Volume  Past Performance  \nReference  \nAttachments (3 \npages)  \nV Completed RFP and Price \nVolume  No page limit  \n  \n2.6.1  Page Limitations  \n  \nPage limitations shall be treated as maximums.  If exceeded, the excess pages will not be read or \nconsidered in the evaluation or award decision of the proposal.  Each page shall be counted \nexcept introductory letter(s), cover pages, table of contents, list of tables or drawings, tabs, and \nglossaries, unless otherwise noted in this provision.  \n  \n3.0 EVALUATION FACTORS FOR AWARD  \n  \n3.1. Basis for Award \n  \nThis section describes the process the Government will use in evaluating the Offerors’ \ncapabilities and proposals for providing a COTS platform for On Demand Coaching Services as \ndescribed in the Statement of Work.  \n  \nThe Government intends to award a single IDIQ to the responsible Offeror whose proposal \nrepresents the best value to the Government after evaluation in accordance with the solicitation.  \nThe best value proposal will be selected using a tradeoff process, as defined in FAR 13.106-2.  \nThe following factors, shall be used to evaluate offers:  \n  \n• Factor 1 – Technical Approach \n• Factor 2 – Management Approach  \n• Factor 3 – Past Performance \n• Factor 4 – Price', start_char_idx=0, end_char_idx=1523, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.6),
#  NodeWithScore(node=TextNode(id_='3dcb6b4d-f503-44a9-b45a-72eded4e2b31', embedding=None, metadata={'page_label': '76', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='15bc8a94-4a73-4f06-881f-630508c9e6e0', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '76', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, hash='f80b64da95c892a86262ed2f48444abd7378780b055347e625e5b862b691e94a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='11b93da7-160f-4b05-b6ba-06e7de71bf17', node_type=<ObjectType.TEXT: '1'>, metadata={'page_label': '75', 'file_name': 'RFP 2032H323 Amendment.pdf', 'file_path': 'rfpparser/RFP 2032H323 Amendment.pdf', 'file_type': 'application/pdf', 'file_size': 1665299, 'creation_date': '2024-03-09', 'last_modified_date': '2024-03-09'}, hash='bd0056bdbc5a93f18c73e464f142f9b9749dbba435342d08c9bee27d6d50a213'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='2dd759d2-ab81-41d4-bc2a-4b394ccec468', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='fd350ac19f0ea9e7211b00f9c991367bbf3349d8cdcf5620bf1a831c8057e162')}, text='2032H323R00065 – AMENDMENT 1   \n76 of 91 \n \uf0b7 Font style and size for illustrations, drawings, and tables are at the Offeror’s discretion, \nbut all labels and markings must be easily readable. Color may be used at the discretion \nof the Offeror. \n \nEvery page, except for the Title Page, shall contain a page number. Blank pages will contain the \nmarking “Page Intentionally Left Blank.” Every page will contain the Offeror’s name and the \nRFP number. It is the Offeror’s responsibility to ensure data considered sensitive is marked as \nsuch. These markings may appear only in the margins. The Offeror shall include the point of \ncontact (name, telephone number, e-mail address, and fax number) that can assist the CO with \nquestions/problems associated with the Offeror’s quote submission. \n \n*Submissions shall be via email in MS Word, MS Excel, and/or .pdf format. \n \n2.2  RFP Response Package  \n \nPhase 1: Demonstration of fully developed COTS On Demand Coaching Platform Resource. \nThe Offerors will provide a demonstration of their COTS On Demand Coaching Platform and \nwill have the opportunity to voluntarily withdraw from Phase 2 participation if they are not able \nto achieve a high confidence rating. \n  \nPhase 2: Full Proposal Submission  \n \nThe RFP response package shall be organized as follows:  \n  \n- Volume I – Cover Letter  \n- Volume II – Technical Approach \n- Volume III - Management Approach  \n- Volume IV – Past Performance  \n- Volume V – Cost/Price  \n \n2.3 Phase 1: Demonstration of existing COTS On Demand Coaching Platform  \n  \n2.3.1  Cover Letter   \n  \nThe Cover Letter shall include the following introductory information,  \n  \n(1) RFP Number 2032H323R00065  \n(2) Name and address of Offeror  \n(3) Name and telephone number of point-of-contact  \n(4) Commercial and Government Entity (CAGE) number  \n(5) DUNS Number  \n(6) Taxpayer Identification Number (TIN)  \n(7) SAM Unique Entity Identifier (UEI) \n(8) Date of submission', start_char_idx=0, end_char_idx=1947, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.0)]

# %%
question = "Identify the Proposal Submission Date &Time, Phase, Contracting Officer, and anything else related to logistics surrounding submission."
nodes_with_scores = retriever.retrieve(
    question
)
_excerpt = ''
i = 0
for node in nodes_with_scores:
    _excerpt += f"Evidence {i+1}:\n"
    _excerpt += node.node.text
    _excerpt += "\n"
    i += 1
display(Markdown(llm.complete(prompt.format(excerpt=_excerpt, question=question)).text))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generated queries:
# 1. What is the deadline for submitting proposals for the project?
# 2. How can I contact the Contracting Officer for inquiries about the proposal submission process?
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The Proposal Submission Date and Time for Phase 1, which is a demonstration of existing Commercial Off the Shelf (COTS) On Demand Coaching Platform Resource, is on or before 4:00 PM Eastern Daylight Savings Time (EDT) THURSDAY, August 10, 2023.
#
# For Phase 2, proposals should be submitted electronically by 2:00 PM EDT on or before THURSDAY, August 31, 2023. These proposals should be sent to the Contracts Specialist, Aaron C. Hill (Aaron.C.Hill@irs.gov) and the Contracting Officer, Angela C. Gallo (Angela.C.Gallo@irs.gov).
#
# All verbal communications and written questions concerning any technical aspect of the solicitation should also be directed to the Contracting Officer, Angela C. Gallo. Written questions must be received by the Contracting Officer at least 7 days before the due date for receipt of proposals.
#
# The Government does not commit to pay any cost for preparation and submission of the proposal. The Contracting Officer, Angela C. Gallo, is the only individual who can legally commit the Government to the expenditure of public funds in connection with this proposed acquisition.
#
# The Government plans to award one contract but reserves the right to award more if it is determined to be in the Government's best interest.

# %%
question = "Statement of Work. What does the applicant's service or product need to ensure?"
nodes_with_scores = rfp.retrieve(
    question
)
print(len(nodes_with_scores))
_excerpt = ''
i = 0
for node in nodes_with_scores:
    _excerpt += f"Evidence {i+1}:\n"
    _excerpt += node.node.text
    _excerpt += "\n"
    i += 1
display(Markdown(llm.complete(prompt.format(excerpt=_excerpt, question=question)).text))
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Generated queries:
# 1. What are the key components of a Statement of Work document?
# 2. How can a Statement of Work help clarify project expectations for both the applicant and the client?
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 3
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# The applicant's service or product needs to ensure a clear understanding of the requirements detailed in the SOW, including applicable laws and regulations. It should demonstrate the capability of the online subscription services with online access to the digital libraries via the website platform to accomplish requirements in SOW Section 3. The proposal should include a description of how the applicant's proposal will accomplish all of the technical requirements listed in the SOW. The applicant should also plan, schedule, initiate, administer, and monitor each task to meet requirements, as well as manage the delivery requirements in SOW Section 4. The service or product should ensure 100% compliance to the standards set in PWS Section 3 Task 1, 2, 3, and 4.
